# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# data = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\_Final\\' + 'Entropy_timestack_0410_101.npy')

# data_500 = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\_Final\Entropy_timestack_0410_101.npy500.npy', allow_pickle=True)
# data_100 = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\_Final\Entropy_timestack_0410_101.npy100.npy', allow_pickle=True)
# data_20 = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\_Final\Entropy_timestack_0410_101.npy20.npy', allow_pickle=True)

# x_500 = data_500[:,0]
# x_100 = data_100[:,0]
# x_20 = data_20[:,0]

# time_500 = data_500[:,4]
# time_100 = data_100[:,4]
# time_20 = data_20[:,4]

data_500 = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\_Final\Entropy_timestack_0410_102.npy', allow_pickle=True)
timestack = np.load(r'C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\timestacks\timestack_0410_102.npy')

x_500 = data_500[:,0]
a = data_500[:,1]
b = data_500[:,2]
c = data_500[:,3]
time_500 = data_500[:,4]

print(x_500[:10])
print(c[:10])




# for i in [500, 100, 20]:

#     x_[i] = data_[i][:,0]
#     # y_f'{i}' = data[:,1]
#     # z_f'{i}' = data[:,2]
#     # xgrid_number_f'{i}' = data[:,3]
#     # time_f'{i}' = data[:,4]
# Out:
# [24.400000000000002 24.400000000000002 24.6 24.8 24.8 25.0
#  25.200000000000003 25.400000000000002 25.6 26.0]
# [122.0 122.0 123.0 124.0 124.0 125.0 126.0 127.0 128.0 130.0]

# %%
plt.figure(figsize=(10,6))
plt.imshow(timestack)

# %%
#plot data
plt.figure(figsize=(15,5))
plt.plot(time_500, x_500)
# plt.plot(time_100, x_100)
# plt.plot(time_20, x_20)

#make axis nice and equal
plt.xlabel('Time')
plt.ylabel('x')

#make time axis nice
# plt.xticks(np.arange(0, 100, 5))
# Out:
# Text(0, 0.5, 'x')

# %%
# # Assuming timestack, time_500, and x_500 are defined already
# plt.figure(figsize=(15, 5))

# # Plot the timestack image
# plt.imshow(timestack, extent=[time_500[0], time_500[-1], 401, timestack.shape[1]], aspect='auto')

# # Overlay the x_500 data on the same axes, plotting in white
# plt.plot(time_500, c, color='red', linewidth=2)

# # Make the axes nice
# plt.xlabel('Time')
# plt.ylabel('x')

# # Adjust the y-limit to match the space axis of the timestack
# # plt.ylim(0, timestack.shape[1])

# # Save the figure (adjust the file name and format as needed)
# plt.savefig('timestack_with_overlay.png', dpi=300, bbox_inches='tight')

# # Show the plot
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming timestack, time_500, and x_500 are defined correctly

# plt.figure(figsize=(15, 5))

# # Plot the timestack image, ensuring the axes match time (518) and space (401)
# plt.imshow(timestack, extent=[time_500[0], time_500[-1], 0, 401], aspect='auto')

# # Overlay the x_500 data on the same axes, plotting in white
# plt.plot(time_500, -c, color='red', linewidth=2)

# # Make the axes nice
# plt.xlabel('Time')
# plt.ylabel('x (space)')

# # Adjust the y-limit to match the space axis of the timestack (401)
# # plt.ylim(0, 401)

# # Save the figure if needed
# plt.savefig('my_figure_corrected.png', dpi=300, bbox_inches='tight')

# # Show the plot
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming timestack, time_500, and x_500 are defined correctly

# plt.figure(figsize=(15, 5))

# # Plot the timestack image, ensuring the axes match time (518) and space (401)
# plt.imshow(timestack, extent=[time_500[0], time_500[-1], 0, 400], aspect='auto')

# # Invert the y-axis to place 0 at the top
# plt.gca().invert_yaxis()

# x_500 = 500 - c

# # Overlay the x_500 data on the same axes, plotting in white
# plt.plot(time_500, x_500, color='red', linewidth=2)

# # Make the axes nice
# plt.xlabel('Time')
# plt.ylabel('x (space)')

# # Adjust the y-limit to match the space axis of the timestack (401)
# plt.ylim(0, 401)

# # Save the figure if needed
# plt.savefig('my_figure_corrected_inverted.png', dpi=300, bbox_inches='tight')

# # Show the plot
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Assuming timestack, time_500, and x_500 are defined correctly

# plt.figure(figsize=(15, 5))

# # Plot the timestack image
# # Set extent to [time_500[0], time_500[-1], 0, 401]
# plt.imshow(timestack, extent=[time_500[0], time_500[-1], 0, 401], aspect='auto')

# # Overlay the x_500 data on the same axes, plotting in white
# plt.plot(time_500, x_500, color='white', linewidth=2)

# # Make the axes nice
# plt.xlabel('Time')
# plt.ylabel('x (space)')

# # Set the y-limit to match the space axis of the timestack (0 at the top and 401 at the bottom)
# plt.ylim(401, 0)  # Set limits so that 0 is at the top

# # Save the figure if needed
# plt.savefig('my_figure_corrected_inverted.png', dpi=300, bbox_inches='tight')

# # Show the plot
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming timestack, time_500, and x_500 are defined correctly

plt.figure(figsize=(15, 5))

# Plot the timestack image
# Set extent to [time_500[0], time_500[-1], 0, 401] and origin to 'upper'
plt.imshow(timestack[100:300], extent=[time_500[0], time_500[-1], 0, 200], aspect='auto', origin='lower')

# Overlay the x_500 data on the same axes, plotting in white
plt.plot(time_500, c, color='red', linewidth=1.5, alpha=0.8)

# Make the axes nice
plt.xlabel('Time')
plt.ylabel('x (space)')

# Set the y-limit to match the space axis of the timestack (0 at the top and 401 at the bottom)
plt.ylim(200, 0)  # Set limits so that 0 is at the top

# Save the figure if needed
plt.savefig('my_figure_corrected_inverted.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
data = np.load(r"C:\Users\katin\MUDE\MDP_CostaRica\Code_meye\processed\runup_from_entropy\normalize_col\Normalized_entropysaturation.npy")
num = np.arange(0, len(data[0]))

print(data[0].shape)
# Out:
# (999,)

# %%
# Assuming timestack, time_500, and x_500 are defined correctly
plt.figure(figsize=(15, 5))

# Plot the timestack image
# Set extent to [time_500[0], time_500[-1], 0, 401] and origin to 'upper'
plt.imshow(timestack[100:300], extent=[num[0], num[-1], 0, 200], aspect='auto', origin='lower')

# Overlay the x_500 data on the same axes, plotting in white
plt.plot(num, data[0], color='red', linewidth=1.5, alpha=0.8)

# Make the axes nice
plt.xlabel('Time')
plt.ylabel('x (space)')

# Set the y-limit to match the space axis of the timestack (0 at the top and 401 at the bottom)
plt.ylim(200, 0)  # Set limits so that 0 is at the top

# Save the figure if needed
plt.savefig('my_figure_corrected_inverted.png', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()
