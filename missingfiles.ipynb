# %%
import rename_file_copy as rename
import os

# %%
# Example usage
folder_path = r'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO'
rename.process_folder(folder_path);
# Out:
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067362.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067362.JPG'
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067363.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067363.JPG'
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067364.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067364.JPG'
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067365.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067365.JPG'
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067366.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067366.JPG'
# Renamed 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067367.JPG' to 'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO\1728067367.JPG'
# ...

# %%
# Define the folder where the pictures are stored
folder_path = r'C:\Users\katin\Downloads\GOPRO_4_10_24\101GOPRO'

# Get a list of all .JPG files in the folder
files = [f for f in os.listdir(folder_path) if f.endswith('.JPG')]

# Extract the numeric part of the filenames and sort them
file_numbers = sorted([int(f.split('.')[0]) for f in files])

# Initialize a list to store missing files
missing_files = []

# Check for missing numbers in the sequence
for i in range(file_numbers[0], file_numbers[-1]):
    if i not in file_numbers:
        missing_files.append(i)

# Output the result
if missing_files:
    print(f"Missing files: {', '.join([str(mf) + '.JPG' for mf in missing_files])}")
else:
    print("No missing files in the sequence.")
# Out:
# No missing files in the sequence.
